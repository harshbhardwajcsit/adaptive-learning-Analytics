# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from kmodes import kmodes
import json
data=pd.read_csv('sample access record data (3).csv')
data = data.drop(["topic_id","course_id","topic_title","category_id","unv_cat_id1","classfctn_id","first_name","unv_cat_id","last_name","unv_org_id","viewerSessionId","accessdate"], axis = 1)
data.head(10)
# Out:
# d:\users\hbhardwaj\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    user_id  organization_id        name topic_locale course_locale  \
# 0       12                8  SuperAdmin           en            en
# 1       12                8  SuperAdmin           en            en
# 2       12                8  SuperAdmin           en            en
# 3       12                8  SuperAdmin           en            en
# 4       12                8  SuperAdmin           en            en
# 5       12                8  SuperAdmin           en            en
# 6       12                8  SuperAdmin           en            en
# 7       12                8  SuperAdmin           en            en
# 8       12                8  SuperAdmin           en            en
# ...

# %%
import csv
import collection
rows = list(csv.reader(open('sample access record data (3).csv', 'r'), delimiter=','))
result = collections.OrderedDict()
for r in rows:
    key = (r[1],r[6])  ## The pair (r[1],r[6]) must be unique
    if key not in result:
        result[key] = r
        print(result.values())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-28fbc0484faa> in <module>()
#       1 import csv
# ----> 2 import collection
#       3 rows = list(csv.reader(open('sample access record data (3).csv', 'r'), delimiter=','))
#       4 result = collections.OrderedDict()
#       5 for r in rows:
#
# ModuleNotFoundError: No module named 'collection'
