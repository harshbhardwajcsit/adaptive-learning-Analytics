# %%
#Instructor description
import pandas as pd
import seaborn as sns  
import matplotlib
import matplotlib.pyplot as plt  
matplotlib.style.use('ggplot')
# %matplotlib inline
#number of courses by institution
data = pd.read_csv('train (2).csv')
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
print(data.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
print(data['Sex'].describe())
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
print((data['Sex']=='male').describe())
# Out:
# count      891
# unique       2
# top       True
# freq       577
# Name: Sex, dtype: object

# %%
print((data['Sex']=='female').describe())
# Out:
# count       891
# unique        2
# top       False
# freq        577
# Name: Sex, dtype: object

# %%
sns.factorplot('Survived',data=data,hue="Sex",kind='count',palette="bright")

# %%
sns.factorplot('Survived',data=data,hue="Pclass" ,kind='count',palette="bright")

# %%
plt.figure(figsize=(100,10))
sns.countplot(x="Age",data=data,hue='Survived')

# %%
print(data['Age'].describe())
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%       20.125000
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data[(data['Sex']=='male')]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# ...

# %%
plt.figure(figsize=(100,100))
sns.lmplot(x='Survived', y='Age',data=data)

# %%
plt.figure(figsize=(100,100))
sns.lmplot(x='Pclass', y='Age',data=data,hue='Survived')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.hist(bins=10,figsize=(30,20),grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000001663BCF8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000016844DA0>]], dtype=object)
